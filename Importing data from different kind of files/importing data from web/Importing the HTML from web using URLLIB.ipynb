# %%
from urllib.request import urlopen, Request

# %%
url = Request('https://www.facebook.com/')

# %%
html = urlopen(url)

# %%
html

# %%
html.read()
# Out:
# b'<!DOCTYPE html>\n<html lang="en" id="facebook" class="no_js">\n<head><meta charset="utf-8" /><meta name="referrer" content="default" id="meta_referrer" /><script>window._cstart=+new Date();</script><script>function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window.Env||{},b(window.Env))}envFlush({"ajaxpipe_token":"AXhomTEaW1xM7w4r","timeslice_heartbeat_config":{"pollIntervalMs":33,"idleGapThresholdMs":60,"ignoredTimesliceNames":{"requestAnimationFrame":true,"Event listenHandler mousemove":true,"Event listenHandler mouseover":true,"Event listenHandler mouseout":true,"Event listenHandler scroll":true},"isHeartbeatEnabled":true,"isArtilleryOn":false},"shouldLogCounters":true,"timeslice_categories":{"react_render":true,"reflow":true},"sample_continuation_stacktraces":true,"dom_mutation_flag":true,"stack_trace_limit":30,"deferred_stack_trace_rate":1000,"timesliceBufferSize":5000,"show_invariant_decoder":false,"compat_i
# ...

# %%
### using the request package

# %%
import requests

# %%
requests.get?

# %%
rs = requests.get("https://www.facebook.com/")

# %%
rs
# Out:
# <Response [200]>

# %% [raw]
# rs.text

# %%
## how ever we cannot get anything from this html tags we need to beautiy the html tags

# %%
## we will use beautifulsoap package

# %%
from bs4 import BeautifulSoup

# %%
data = BeautifulSoup(rs.text,'lxml')

# %%
type(data)
# Out:
# bs4.BeautifulSoup

# %%
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no_js" id="facebook" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="default" id="meta_referrer" name="referrer"/>
#   <script>
#    window._cstart=+new Date();
#   </script>
#   <script>
# ...

# %%
data.title
# Out:
# <title id="pageTitle">Facebook - Log In or Sign Up</title>

# %%
data.find_all('a')
# Out:
# [<a aria-expanded="false" aria-haspopup="true" class="_42ft _4jy0 _55pi _2agf _4o_4 _63xb _p _4jy3 _517h _51sy" href="#" id="u_0_15" rel="toggle" role="button" style="max-width:200px;"><span class="_55pe">Sections of this page</span><span class="_4o_3 _3-99"><i class="img sp_quYBxKcZF-N sx_cef969"></i></span></a>,
#  <a aria-expanded="false" aria-haspopup="true" class="_42ft _4jy0 _55pi _2agf _4o_4 _3_s2 _63xb _p _4jy3 _4jy1 selected _51sy" href="#" id="u_0_17" rel="toggle" role="button" style="max-width:200px;" tabindex="-1"><span class="_55pe">Accessibility Help</span><span class="_4o_3 _3-99"><i class="img sp_quYBxKcZF-N sx_e0a388"></i></span></a>,
#  <a href="https://www.facebook.com/" title="Go to Facebook Home"><i class="fb_logo img sp_quYBxKcZF-N sx_644351"><u>Facebook</u></i></a>,
#  <a href="https://www.facebook.com/recover/initiate?lwv=110&amp;ars=royal_blue_bar">Forgot account?</a>,
# ...

# %%
data.find_all('href')
# Out:
# []

# %% [markdown]
# ## We can import the data from web in the form of html
#  ### we have lots of modules to connct to WWW
#  * urllib package we have request and openurl class which get the data from the www

# %% [markdown]
# **from urllib.request import request, openurl.
# **First the request from the url.
# **url = request('enter the url').
# **now Use the openurl to get the data from the webiste.
# ** html = openurl(url)

# %%
## we can requests module to do this

# %%
#After getiing the data from the website we cant read it properly so we will be using bs4 module BeautifulSoap class to pretify the data
